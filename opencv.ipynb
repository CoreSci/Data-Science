# %%
#Here's a simple example of using OpenCV with Python to read an image and display it
#Make sure to replace 'path/to/your/image.jpg' with the actual path to your image file. This example uses the imshow function to display the image,
#and waitKey(0) waits for a key press before closing the window. Alternatively, you can use Matplotlib to display the image

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load an image from file
image_path = 'signature.jpg'
img = cv2.imread(image_path)

# %%
# Display the image using OpenCV. Not suitable in docker with jupyter. Use matplotlib instead.
#cv2.imshow('Image', img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
#Use matplotlib here.
# Convert BGR image to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Display the image using Matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Turn off axis labels
plt.show()
